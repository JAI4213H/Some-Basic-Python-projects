# %%
from ollama import chat

# %%
def summarise_memory(x: list):
    memory_content = "  ".join([i["content"] for i in x])
    messages_format = [{
        
        
        "role" : "user",
        
        "content": f"Summarise the memory of model (dont use special characters such as * or anything else): {memory_content}"
    }]

    summarised_memory = chat(
        model="qwen3:4b",
        messages = messages_format,
        think = True
    )
    return summarised_memory.message.content

# %%
counter = 0
memory = []
while True:
    if counter > 2:
        counter = 0
        print("\n\nTrying To Summarise Memory\n\n")
        temp = summarise_memory(memory)
        memory.clear()
        memory.append(
            {"role":"system",
            "content" : f"Memory of whole chat is: {temp} "}
        )
        
        print("Memory Updated")
        print("\n",memory[0]["content"])
    prompt = str(input("Enter Your Prompt: "))
    
    memory.append({
        "role":"user",
        "content": prompt
    })

    output = chat(
        model="qwen3:1.7b",
        messages = memory,
        think = True
    )
    print(output.message.content)
    memory.append({
        "role": "assistant",
        "content": output.message.content
    })
    counter +=1
# Out:
# Enter Your Prompt:  Hi, My name is JAi
# Hi! I'm JAi. How can I assist you today? Whether it's helping with a creative project, finding a nickname, or something else, just let me know what you need! 😊
# Enter Your Prompt:  I love Animals
# Oh, animals are so fascinating! 🐾 Do you want to explore something specific, like a favorite animal, a creative project, or even a nickname? I’d love to help! 😊 What’s your favorite animal or what kind of project are you curious about?
# Enter Your Prompt:  I also have a dog named Nancy.
# Oh, Nancy is such a cute companion! 🐾 Do you want to create a nickname for her, come up with a fun activity to play with her, or maybe brainstorm a creative project involving her? I’d love to help! 😊 What’s your favorite way to interact with her?
#
#
# Trying To Summarise Memory
